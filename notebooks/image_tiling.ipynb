# %%
import pytorch_toolbelt
from pytorch_toolbelt.inference.tiles import ImageSlicer, CudaTileMerger
from pytorch_toolbelt.utils.torch_utils import tensor_from_rgb_image, to_numpy
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('/home/chandanv/Drive/Competitions/Kaggle/SIIM/SIIM_ISIC/data/raw/test/ISIC_0052060.jpg')
plt.imshow(image)
plt.show()

# %%
image.shape
# Out:
# (4000, 6000, 3)

# %%
tiler = ImageSlicer(image.shape, tile_size = (512, 512), tile_step= (512, 512))

# %%
tiler

# %%
512+256

# %%
tiles = [tensor_from_rgb_image(tile) for tile in tiler.split(image)]

# %%
arrays = [tile for tile in tiles]

# %%
stack_up = np.stack(arrays, axis= 0)

# %%
stack_up.shape
# Out:
# (96, 3, 512, 512)

# %%
plt.imshow(np.transpose(stack_up[60], (1, 2, 0)))

# %%
from PIL import Image
im = Image.fromarray(ti)

# %%
plt.imshow(im)
